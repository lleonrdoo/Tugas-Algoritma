# %% [markdown]
# # 5.21 Pandas

# %%
# berikut dilakukan inisialisasi library 'pandas' sebagai 'pd'
import pandas as pd

# %% [markdown]
# #

# %% [markdown]
# ## 5.21.1 Membaca File Data pada Pandas

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.21.1
# Membaca File Data
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# diperlukan inisialisasi library pandas kembali
import pandas as pd

# berikut inisialisasi data csv dengan memanggil data pada storage  file
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')
data31
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# #

# %% [markdown]
# ## 5.21.2 Properti pada Pandas

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.21.2
# Penggunaan Properti pada Pandas
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# diperlukan inisialisasi library pandas kembali
import pandas as pd
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut pemanggilan variabel dengan urutan baris 1-4
print("Pernyataan (1) : ")
print(data31.head(4))
print('\n\n')

# berikut pemanggilan variabel berdasarkan nama-nama kolomnya
print("Pernyataan (2) :")
print(data31.columns)
print('\n\n')

# berikut pemanggilan variabel berdasarkan inisial string kolom datanya
print("Pernyataan (3) :")
print(data31['sepal length (cm)'])
print('\n\n')

# berikut pemanggilan variabel berdasarkan inisial string kolom dan urutan index barisnya
print("Pernyataan (4) :")
print(data31['sepal length (cm)'][0])
print('\n\n')

# berikut pemanggilan variabel berdasarkan inisial string kolom dan urutan index barisnya
print("Pernyataan (5) :")
print(data31['sepal length (cm)'][1:5])
print('\n\n')

# berikut pemanggilan variabel berdasarkan inisial string dua buah kolom dan urutan index baris kedua kolomnya
print("Pernyataan (6) :")
print(data31[['sepal length (cm)','sepal width (cm)']][1:5])
print('\n\n')

# berikut pemanggilan variabel berdasarkan urutan baris 
# dan kolom-kolom pada baris tersebut akan diurutkan secara vertikal
# catatan : hal ini berlaku jika hanya terdapat 1 index yang diminta
print("Pernyataan (7) :")
print(data31.iloc[1])
print('\n\n')

# berikut pemanggilan variabel berdasarkan urutan baris sesuai index baris yang diminta
print("Pernyataan (8) :")
print(data31.iloc[1:5])
print('\n\n')

# berikut pemanggilan variabel berdasarkan inisial string tertentu yang dioperasikan operator perbandingan pada data tertentu
print("Pernyataan (9) :")
print(data31.loc[data31['sepal width (cm)']==3.0])
# Out:
# Pernyataan (1) :
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
#
#
#
# Pernyataan (2) :
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')
#
#
#
# Pernyataan (3) :
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal length (cm), Length: 150, dtype: float64
#
#
#
# Pernyataan (4) :
# 5.1
#
#
#
# Pernyataan (5) :
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: sepal length (cm), dtype: float64
#
#
#
# Pernyataan (6) :
#    sepal length (cm)  sepal width (cm)
# ...

# %% [markdown]
# #

# %% [markdown]
# ## 5.21.3 Mengurutkan data pada Pandas

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.21.3
# Penggunaan Fungsi Pengurutan pada Pandas
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

import pandas as pd
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut variabel yang ditunjukkan akan diurutkan berdasarkan inisial string yang diminta
# urutannya akan berdasarkan data terkecil ke terbesar
print("Pernyataan (1) :")
print(data31.sort_values('sepal length (cm)'))
print('\n\n')

# berikut variabel yang ditunjukkan akan diurutkan berdasarkan inisial string yang diminta
# urutannya akan berdasarkan data terbesar ke terkecil karena terdapat fungsi 'ascending=False'
# 'ascending=False' digunakan untuk menyatakan perintah sebaliknya dari yang diminta
print("Pernyataan (2) :")
print(data31.sort_values('sepal length (cm)', ascending=False))
print('\n\n')

# berikut variabel yang ditunjukkan akan diurutkan berdasrkan inisial string yang diminta
# inisial string dapat lebih dari 1 namun diperlukan ',' untuk memisahkan satu sama lain
print("Pernyataan (3) :")
print(data31.sort_values(['sepal length (cm)' , 'petal length (cm)' ,'sepal width (cm)' , 'petal width (cm)']))
# Out:
# Pernyataan (1) :
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 13                 4.3               3.0                1.1               0.1
# 42                 4.4               3.2                1.3               0.2
# 38                 4.4               3.0                1.3               0.2
# 8                  4.4               2.9                1.4               0.2
# 41                 4.5               2.3                1.3               0.3
# ..                 ...               ...                ...               ...
# 122                7.7               2.8                6.7               2.0
# 118                7.7               2.6                6.9               2.3
# 117                7.7               3.8                6.7               2.2
# 135                7.7               3.0                6.1               2.3
# 131                7.9               3.8                6.4               2.0
#
# ...

# %% [markdown]
# #

# %% [markdown]
# ## 5.21.4 Mengubah data pada Pandas

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.21.4
# Mengubah Data didalam Dataframe
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

import pandas as pd
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut adalah pengubahan data pada inisial kolom yang dituju dengan pengoprasian suatu fungsi
# data string yang akan diubah diinput kedalam variabel yang dituju
# dan data yang akan diubah di inputkan pada variabel yang memiliki data string yang baru
data31['dua kali sepal length (cm)'] = 2*data31['sepal length (cm)']
data31
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      dua kali sepal length (cm)
# ...

# %% [markdown]
# #

# %%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.21.4
# Menghapus Data didalam Dataframe
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

import pandas as pd
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut inisialisasi data yang akan ditambahkan pada kolom dataframe
data31['dua kali sepal length (cm)'] = 2*data31['sepal length (cm)']

# berikut penghapusan kolom yang dituju dengan fungsi 'drop()'
# fungsi 'drop()' digunakan untuk menghapus kolom yang diminta pada data string
bunga_iris = data31.drop(columns=['dua kali sepal length (cm)'])
bunga_iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# #

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.21.4
# Menambahkan Data didalam Dataframe dengan Operasi Data
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

import pandas as pd
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut penambahan kolom pada data dengan menginisialkan data string 
# dan ditambahkan fungsi yang diinginkan untuk diinput 
data31['Kemungkinan luas sebuah sepal'] = data31['sepal length (cm)'] * data31['sepal width (cm)']
data31
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# ...

# %% [markdown]
# #

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.21.4
# Penghapusan Data pada Dataframe
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

import pandas as pd
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut penghapusan kolom yang dituju dengan fungsi 'drop()'
# fungsi 'drop()' digunakan untuk menghapus kolom yang diminta pada data string
data31 = data31.drop(columns=['Kemungkinan luas sebuah sepal'])
data31
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      dua kali sepal length (cm)
# ...

# %% [markdown]
# #

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.21.4
# Penambahan Data pada Dataframe dengan Mengetahui Lokasi Data
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

import pandas as pd
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut inisialisasi variabel dengan data string yang dituju menggunakan fungsi 'iloc' dan fungsi 'sum(axis=1)'
# fungsi 'iloc' digunakan untuk mengetahui index baris dari data string
# fungsi 'sum(axis=1)' digunakan untuk operasi penjumlahan kolom
data31['Kemungkinan luas sebuah petal'] = data31.iloc[:,4:7].sum(axis=1)
data31
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# ...

# %% [markdown]
# #

# %% [markdown]
# ## 5.21.5 Menyimpan data menggunakan Pandas

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.21.5
# Penyimpanan Data CSV
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

import pandas as pd
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut data variabel yang akan disimpan pada storage file device dengan fungsi 'to_csv'
# sehingga, data yang disimpan akan berada pada disk user dengan tipe file 'csv'
# 'sep' adalah separator yang berfungsi sebagai pemisah dan defaultnya adalah spasi
# 'index=False' digunakan untuk menunjukkan data ke csv tanpa index baris 
data31.to_csv('data_bunga_iris.csv' , index=False , sep = '\t')

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.21.5
# Penyimpanan Data CSV
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

import pandas as pd
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut data variabel yang akan disimpan pada storage file device dengan fungsi 'to_csv'
# sehingga, data yang disimpan akan berada pada disk user dengan tipe file'csv'
# 'index=False' digunakan untuk menunjukkan data ke csv tanpa index baris 
data31.to_csv('data_bunga_iris.csv' , index=False)

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.21.5
# Penyimpanan Data Excel
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

import pandas as pd
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut data variabel yang akan disimpan pada storage file device dengan fungsi 'to_excel'
# sehingga, data yang disimpan akan berada pada disk user dengan tipe file 'Microsoft Excel'
# 'index=False' digunakan untuk menunjukkan data ke excel tanpa index baris
data31.to_excel('data_bunga_iris.xlsx' ,  index=False)

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.21.5
# Pemanggilan Data CSV
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

import pandas as pd
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut pemanggilan data csv pada storage file device dengan fungsi 'read_csv' pada variabel 'data'
data = pd.read_csv('data_bunga_iris.csv')
print(data)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.21.5
# Pemanggilan Data CSV
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

import pandas as pd
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut pemanggilan data csv pada storage file device dengan fungsi 'read_csv' pada variabel 'data'4
# ' delimiter='t' ' adalah separator yang berfungsi sebagai pemisah dan defaultnya adalah spasi
data2 = pd.read_csv('data_bunga_iris.csv' , delimiter='\t')
print(data2)
# Out:
#     sepal length (cm),sepal width (cm),petal length (cm),petal width (cm)
# 0                                      5.1,3.5,1.4,0.2
# 1                                      4.9,3.0,1.4,0.2
# 2                                      4.7,3.2,1.3,0.2
# 3                                      4.6,3.1,1.5,0.2
# 4                                      5.0,3.6,1.4,0.2
# ..                                                 ...
# 145                                    6.7,3.0,5.2,2.3
# 146                                    6.3,2.5,5.0,1.9
# 147                                    6.5,3.0,5.2,2.0
# 148                                    6.2,3.4,5.4,2.3
# 149                                    5.9,3.0,5.1,1.8
#
# [150 rows x 1 columns]

# %% [markdown]
# #

# %% [markdown]
# ## 5.21.6 Menyaring data menggunakan Pandas

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.21.6
# Penyaringan Data Berdasarkan Syaratnya
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

import pandas as pd
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut penyaringan data berdasarkan inisial string yang dituju dengan fungsi 'loc' dan dengan operator perbandingan 
print(data31.loc[data31['sepal length (cm)'] == 5.0])
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 4                 5.0               3.6                1.4               0.2
# 7                 5.0               3.4                1.5               0.2
# 25                5.0               3.0                1.6               0.2
# 26                5.0               3.4                1.6               0.4
# 35                5.0               3.2                1.2               0.2
# 40                5.0               3.5                1.3               0.3
# 43                5.0               3.5                1.6               0.6
# 49                5.0               3.3                1.4               0.2
# 60                5.0               2.0                3.5               1.0
# 93                5.0               2.3                3.3               1.0

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.21.6
# Penyaringan Data Berdasarkan Dua Buah Syarat
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

import pandas as pd
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut penyaringan data berdasarkan inisial string yang dituju dengan fungsi 'loc' dan dengan operator perbandingan 
# data yang diminta dapat lebih dari satu , namun dengan syarat menambahkan '&'
print(data31.loc[(data31['sepal length (cm)'] == 5.0) &
                 (data31['petal length (cm)'] == 1.6)])
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 25                5.0               3.0                1.6               0.2
# 26                5.0               3.4                1.6               0.4
# 43                5.0               3.5                1.6               0.6

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.21.6
# Penyaringan Data Berdasarkan Tiga Buah Syarat
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

import pandas as pd
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut penyaringan data berdasarkan inisial string yang dituju dengan fungsi 'loc' dan dengan operator perbandingan 
# data yang diminta dapat lebih dari satu , namun dengan syarat menambahkan '&'
print(data31.loc[(data31['sepal length (cm)'] == 5.0) &
                 (data31['petal length (cm)'] == 1.6) & 
                 (data31['sepal width (cm)'] > 3.0)])
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 26                5.0               3.4                1.6               0.4
# 43                5.0               3.5                1.6               0.6

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.21.6
# Penyaringan Data Berdasarkan Syarat Data String
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

import pandas as pd
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut penyaringan data berdasarkan inisial string yang dituju dengan fungsi 'loc'dan dengan fungsi 'str.contains()'
# namun, karena didalam inisial string yang dituju hanya terdapat data integer, makan 'str.contains()'' mengalami error
print(data31.loc[data31['sepal length (cm)'].str.contains(3.0)])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15384\890804726.py in <module>
#       1 # berikut penyaringan data berdasarkan inisial string yang dituju dengan fungsi 'loc'dan dengan fungsi 'str.contains()'
# ----> 2 print(data31.loc[data31['sepal length (cm)'].str.contains(3.0)])
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
# ...

# %%
import re
# digunakan untuk bekerja dengan ekspresi reguler 'regex'
# 'regex' merupakan urutan karakter yang membentuk pola pencarian

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.21.6
# Penyaringan Data Berdasarkan Syarat dan Regex
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

import pandas as pd
import re
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut penyaringan data berdasarkan inisial string yang dituju dengan fungsi 'loc'dan dengan fungsi 'str.contains()'
# fungsi 'regex = True' digunakan untuk mengurutan karakter yang membentuk pola untuk menemukan, mengganti, dan mengekstrak data tekstual 
# namun, karena didalam inisial string yang dituju hanya terdapat data integer, makan 'str.contains()'' mengalami error
print(data31.loc[data31['sepal length (cm)'].str.contains(3.0|3.5 , regex=True)])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15384\651801899.py in <module>
#       1 # berikut penyaringan data berdasarkan inisial string yang dituju dengan fungsi 'loc'dan dengan fungsi 'str.contains()'
#       2 # fungsi 'regex = True' digunakan untuk mengurutan karakter yang membentuk pola untuk menemukan, mengganti, dan mengekstrak data tekstual
# ----> 3 print(data31.loc[data31['sepal length (cm)'].str.contains(3.0|3.5 , regex=True)])
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
# ...

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.21.6
# Penyaringan Data Berdasarkan Syarat, Regex, dan Flags
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

import pandas as pd
import re
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut penyaringan data berdasarkan inisial string yang dituju dengan fungsi 'loc'dan dengan fungsi 'str.contains()'
# fungsi 'regex = True' digunakan untuk mengurutan karakter yang membentuk pola untuk menemukan, mengganti, dan mengekstrak data tekstual 
# fungsi 'flags=re.I' digunakan sebagai argumen ke metode pencarian untuk mengaktifkan pencarian yang tidak sensitif huruf
# namun, karena didalam inisial string yang dituju hanya terdapat data integer, makan 'str.contains()'' mengalami error
print(data31.loc[data31['sepal length (cm)'].str.contains(3.0|3.5 , flags=re.I , regex=True)])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15384\1729881437.py in <module>
#       3 # fungsi 'flags=re.I' digunakan sebagai argumen ke metode pencarian untuk mengaktifkan pencarian yang tidak sensitif huruf
#       4 # namun, karena didalam inisial string yang dituju hanya terdapat data integer, makan 'str.contains()'' mengalami error
# ----> 5 print(data31.loc[data31['sepal length (cm)'].str.contains(3.0|3.5 , flags=re.I , regex=True)])
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
# ...

# %% [markdown]
# #

# %% [markdown]
# ## 5.21.7 Pengelompokan data menggunakan Pandas

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.21.7
# Pengelompokkan Data yang Dituju dengan Fungsi Mean
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

import pandas as pd
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut pengelompokan data variabel berdasarkan inisial string yang diminta dengan fungsi 'mean()' dan 'sort_values'
# 'mean()' akan menghitung nilai rata-rata dari sebuah kolom numerik di dataframe
# 'sort_values' akan mengurutkan berdasrkan nilai terkecil ke terbesar data string yang diminta
# 'ascending=True' menentukan pengurutan 'sort_values' dari nilai terkecil ke terbesar
print(data31.groupby(['sepal length (cm)']).mean().sort_values('petal length (cm)', ascending=True))
# Out:
#                    sepal width (cm)  petal length (cm)  petal width (cm)
# sepal length (cm)
# 4.3                        3.000000           1.100000          0.100000
# 4.5                        2.300000           1.300000          0.300000
# 4.6                        3.325000           1.325000          0.225000
# 4.4                        3.033333           1.333333          0.200000
# 4.7                        3.200000           1.450000          0.200000
# 5.3                        3.700000           1.500000          0.200000
# 4.8                        3.180000           1.580000          0.200000
# 5.1                        3.477778           1.722222          0.400000
# 5.0                        3.120000           1.840000          0.430000
# 5.4                        3.550000           2.033333          0.516667
# 5.2                        3.425000           2.075000          0.475000
# 4.9                        2.950000           2.266667          0.550000
# ...

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.21.7
# Pengelompokkan Data yang Dituju dengan Fungsi Mean
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%


import pandas as pd
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut pengemlompokan data variabel berdasarkan inisial string yang diminta dengan fungsi 'mean()'
# 'mean()' akan menghitung nilai rata-rata dari sebuah kolom numerik pada dataframe
print(data31.groupby(['petal length (cm)']).mean())
# Out:
#                    sepal length (cm)  sepal width (cm)  petal width (cm)
# petal length (cm)
# 1.0                         4.600000          3.600000          0.200000
# 1.1                         4.300000          3.000000          0.100000
# 1.2                         5.400000          3.600000          0.200000
# 1.3                         4.842857          3.228571          0.257143
# 1.4                         4.915385          3.353846          0.207692
# 1.5                         5.146154          3.569231          0.238462
# 1.6                         4.914286          3.342857          0.285714
# 1.7                         5.400000          3.600000          0.350000
# 1.9                         4.950000          3.600000          0.300000
# 3.0                         5.100000          2.500000          1.100000
# 3.3                         4.950000          2.350000          1.000000
# 3.5                         5.350000          2.300000          1.000000
# ...

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.21.7
# Pengelompokkan Data yang Dituju dengan Fungsi Sum
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%


import pandas as pd
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut pengelompokan data variabel berdasarkan inisial string yang diminta dengan fungsi 'sum()'
# fungsi 'sum()' digunakan untuk menghitung jumlah dari sebuah kolom numerik pada dataframe
print(data31.groupby(['sepal length (cm)']).sum())
# Out:
#                    sepal width (cm)  petal length (cm)  petal width (cm)
# sepal length (cm)
# 4.3                             3.0                1.1               0.1
# 4.4                             9.1                4.0               0.6
# 4.5                             2.3                1.3               0.3
# 4.6                            13.3                5.3               0.9
# 4.7                             6.4                2.9               0.4
# 4.8                            15.9                7.9               1.0
# 4.9                            17.7               13.6               3.3
# 5.0                            31.2               18.4               4.3
# 5.1                            31.3               15.5               3.6
# 5.2                            13.7                8.3               1.9
# 5.3                             3.7                1.5               0.2
# 5.4                            21.3               12.2               3.1
# ...

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.21.7
# Pengelompokkan Data yang Dituju dengan Fungsi Count
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%


import pandas as pd
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut pengelompokan data variabel berdasarkan inisial string yang diminta dengan fungsi 'count()'
# fungsi 'count()' digunakan untuk menampilkan jumlah kolom dan baris pada inisial string yang dituju
print(data31.groupby(['sepal length (cm)']).count())
# Out:
#                    sepal width (cm)  petal length (cm)  petal width (cm)
# sepal length (cm)
# 4.3                               1                  1                 1
# 4.4                               3                  3                 3
# 4.5                               1                  1                 1
# 4.6                               4                  4                 4
# 4.7                               2                  2                 2
# 4.8                               5                  5                 5
# 4.9                               6                  6                 6
# 5.0                              10                 10                10
# 5.1                               9                  9                 9
# 5.2                               4                  4                 4
# 5.3                               1                  1                 1
# 5.4                               6                  6                 6
# ...

# %% [markdown]
# #

# %% [markdown]
# # 5.22 Matplotlib

# %%
# berikut inisialisasi library sesuai dengan singkatannya
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #

# %% [markdown]
# ## 5.22.1 Grafik sederhana dengan Matplotlib

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.22.1
# Membentuk Grafik Sederhana dengan Library Matplotlib
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut adalah inisialisasi variabel berdasarkan kolom pada data yang diminta
x = data31['sepal length (cm)']
y = data31['petal length (cm)']

# fungsi 'plot' digunakan untuk menampilkan data koordinat kedalam garis koordinat 
plt.plot(x,y)

# fungsi 'title' digunakan untuk menamai koordinat
plt.title("Grafik sepal dan petal")

# fungsi '..label' digunakan untuk menamai sumbu yang dimaksud pada koordinat
plt.xlabel('X = panjang sepal')
plt.ylabel('Y = panjang petal')
# Out:
# Text(0, 0.5, 'Y = panjang petal')

# %% [markdown]
# #

# %% [markdown]
# ## 5.22.2 Properti Pembuatan Grafik dengan Matplotlib

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.22.2
# Membentuk Grafik dengan Properti pada Library Matoplotlib (1)
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut inisialisasi variabel dengan data variabel sesuai inisialisasi kolom string yang dituju
x = data31['sepal length (cm)']
y = data31['petal length (cm)']
x1 = data31['sepal width (cm)']
y1 = data31['petal width (cm)']

# berikut pembentukan sumbu koordinat yang berukuran 15 x 15 inch dengan resolusi gambar 500 dpi
# fungsi 'figure()' digunakan untuk menggambarkan bentuk dari koordinatnya
# fungsi 'figsize()' digunakan untuk menentukan ukuran gambar
# fungsi 'dip' digunakan untuk menentukan resolusi gambar
plt.figure(figsize=(15,15), dpi=500) 

# berikut pembentukan linier pertama dengan nama, warna, penanda, dan bentuk garis tertentu
# fungsi 'label' digunakan untuk menamai linier yang diminta
# fungsi 'color' digunakan untuk menentukan warna linier
# fungsi 'linewidth' digunakan untuk ketebalan linier
# fungsi 'marker' digunakan untuk menentukan penanda pada titik yang dituju
# fungsi 'makersize' digunakan unutuk menentukan ukuran penanda
# fungsi 'markeredgecolor' digunakan untuuk menentukan warna penanda
# fungsi 'markersize' digunakan untuk menentukan ukuran penanda
plt.plot(x,y, label = 'Grafik length' ,  color = 'blue' , 
         linewidth = 3 , marker = '*' , markersize = 15 , 
         markeredgecolor = 'orange' , linestyle='-')

# berikut pembentukan garis liniear kedua dengan nama, warna, penanda, dan bentuk garis tertentu
# fungsi 'label' digunakan untuk menamai linier yang diminta
# fungsi 'linewidth' digunakan untuk ketebalan linier
# fungsi 'marker' digunakan untuk menentukan penanda pada titik yang dituju
# fungsi 'makersize' digunakan unutuk menentukan ukuran penanda
# fungsi 'markeredgecolor' digunakan untuk menentukan warna penanda
plt.plot(x1,y1, label = 'Garik width', marker = '*' , 
         markersize = 15 , markeredgecolor = 'orange' )

# berikut penamaan koordinat dengan fungsi 'title()'
# fungsi 'title()' digunakan untuk memasukan data string dan ukuran font
# fungsi 'fontdict' digunakan untuk menentukan ukuran font
plt.title('Grafik Bunga Iris ', fontdict = {'fontname' : 'DejaVu Sans' , 'fontsize' : 12})

# berikut inisialisasi sumbu x dan y dengan penamaan menggunakan data string
# fungsi 'fontdict' digunakan untuk menentukan ukuran font
plt.xlabel('X', fontdict={'fontname' : 'DejaVu Sans' , 'fontsize' : 6})
plt.ylabel('Y', fontdict={'fontname' : 'DejaVu Sans' , 'fontsize' : 6})

# berikut pembentukan output dari label x dan y
plt.xticks(data31['sepal length (cm)'])
plt.yticks(data31['petal length (cm)'])
plt.legend()

# berikut pembentukan output dari label x1 dan y1
plt.xticks(data31['sepal width (cm)'])
plt.yticks(data31['petal width (cm)'])
plt.legend()

# berikut penyimpanan figure pada 'grafik.png' dengan resolusi 500 dpi
plt.savefig('grafik.png' , dpi=500)

# berikut fungsi 'show()' yang digunakan untuk mengeluarkan output figure
plt.show()

# %% [markdown]
# #

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.22.2
# Membentuk Grafik dengan Properti pada Library Matoplotlib (2)
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut inisialisasi variabel dengan data variabel sesuai inisialisasi kolom string yang dituju
x = [-5,-3,-1,0,1,3,5,6]
y = [31,13,3,1,1,7,21,31]
x1 = [-3,-2,-1,1,2,3]
y1 = [0.5,1,1.5,2.5,3,3.5]

# berikut pembentukan sumbu koordinat yang berukuran 12 x 12 inch dengan resolusi gambar 500 dpi
# fungsi 'figure()' digunakan untuk menggambarkan bentuk dari koordinatnya
# fungsi 'figsize()' digunakan untuk menentukan ukuran gambar
# fungsi 'dip' digunakan untuk menentukan resolusi gambar
plt.figure(figsize=(12,12), dpi=500) 

# berikut pembentukan linier pertama dengan nama, warna, penanda, dan bentuk garis tertentu
# fungsi 'label' digunakan untuk menamai linier yang diminta
# fungsi 'color' digunakan untuk menentukan warna linier
# fungsi 'linewidth' digunakan untuk ketebalan linier
# fungsi 'marker' digunakan untuk menentukan penanda pada titik yang dituju
# fungsi 'makersize' digunakan unutuk menentukan ukuran penanda
# fungsi 'markeredgecolor' digunakan untuuk menentukan warna penanda
# fungsi 'markersize' digunakan untuk menentukan ukuran penanda
plt.plot(x,y, label = 'Grafik Y= X^2 - X + 1' , color = 'blue' , 
         linewidth = 3 , marker = '*' , markersize = 15 , 
         markeredgecolor='red' , linestyle='-.')

# berikut pembentukan garis liniear kedua dengan nama, warna, penanda, dan bentuk garis tertentu
# fungsi 'label' digunakan untuk menamai linier yang diminta
# fungsi 'linewidth' digunakan untuk ketebalan linier
# fungsi 'marker' digunakan untuk menentukan penanda pada titik yang dituju
# fungsi 'makersize' digunakan unutuk menentukan ukuran penanda
# fungsi 'markeredgecolor' digunakan untuk menentukan warna penanda
plt.plot(x1,y1 , marker = '*' , markeredgecolor = 'red' ,
         markersize = 15 , label = 'Grafik Y = 1/2X + 2')

# berikut penamaan koordinat dengan fungsi 'title()'
# fungsi 'title()' digunakan untuk memasukan data string dan ukuran font
# fungsi 'fontdict' digunakan untuk menentukan ukuran font
plt.title('Grafik Parabola dengan Garis yang Memotongnya ', fontdict = {'fontname' : 'DejaVu Sans' , 'fontsize' : 12})

# berikut inisialisasi sumbu x dan y dengan penamaan menggunakan data string
# fungsi 'fontdict' digunakan untuk menentukan ukuran font
plt.xlabel('X', fontdict={'fontname' : 'DejaVu Sans' , 'fontsize' : 6})
plt.ylabel('Y', fontdict={'fontname' : 'DejaVu Sans' , 'fontsize' : 6})

# berikut pembentukan output dari label x dan y
plt.xticks([-5,-3,-1,0,1,3,5,6])
plt.yticks([31,13,3,1,1,7,21,31])
plt.legend()

# berikut pembentukan output dari label x1 dan y1
plt.xticks([-3,-2,-1,1,2,3])
plt.yticks([0.5,1,1.5,2.5,3,3.5])
plt.legend()

# berikut penyimpanan figure pada 'grafik.png' dengan resolusi 500 dpi
plt.savefig('grafik.png' , dpi=500)

# berikut fungsi 'show()' yang digunakan untuk mengeluarkan output figure
plt.show()

# %% [markdown]
# #

# %% [markdown]
# ## 5.22.3 Histogram sederhana dengan Matplotlib

# %%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.22.3
# Membentuk Histogram Sederhana dengan Library Matoplotlib (1)
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut inisialisasi variabel dengan menginput data yang dituju sesuai dengan kolom yang diminta
sepal = data31['sepal length (cm)']
petal = data31['petal length (cm)']

# berikut inisialisasi variabel dengan menginput data yang dituju sesuai dengan kolom yang diminta
# namun terdapat operator perbandingan sebagai pengelompokan data kolom yang diminta
sepal1 = data31['sepal width (cm)']
petal1 = data31['petal width (cm)']

# berikut inisialisasi sumbu x dan y dengan penamaan menggunakan data string
# fungsi 'fontdict' digunakan untuk menentukan ukuran font
plt.xlabel('Sepal (cm)')
plt.ylabel('Petal (cm)')

# berikut penggunaan fungsi 'bar()' untuk membentuk histogram
print(plt.bar(sepal,sepal1))
print(plt.bar(petal,petal1))
# Out:
# <BarContainer object of 150 artists>
# <BarContainer object of 150 artists>

# %% [markdown]
# #

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.22.3
# Membentuk Grafik Sederhana dengan Library Matoplotlib (2)
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut inisialisasi variabel dengan menginput data integer
x = [-5,-3,-1,0,1,3,5,6]
y = [31,13,3,1,1,7,21,31]

# berikut inisialisasi sumbu x dan y dengan penamaan menggunakan data string
plt.xlabel('X')
plt.ylabel('Y')

# berikut penggunaan fungsi 'bar()' untuk membentuk histogram
print(plt.bar(x,y))
# Out:
# <BarContainer object of 8 artists>

# %% [markdown]
# #

# %% [markdown]
# ## 5.22.4 Properti Pembuatan Histogram dengan Matplotlib

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Latihan 5.22.4
# Membentuk Histogram dengan Properti pada Library Matoplotlib
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data31 = pd.read_csv('C:/Users/santi/bunga_iris.csv')

# berikut inisialisasi variabel dengan menginput data integer
x = [-5,-3,-1,0,1,3,5,6]
y = [31,13,3,1,1,7,21,31]

# berikut pembentukan sumbu koordinat yang berukuran 12 x 12 inch dengan resolusi gambar 500 dpi
# fungsi 'figure()' digunakan untuk menggambarkan bentuk dari koordinatnya
# fungsi 'figsize()' digunakan untuk menentukan ukuran gambar
plt.figure(figsize=(5,5))

# berikut inisialisasi variabel dengan fungsi 'bar()' beserta menentukan warnanya
hist = plt.bar(x,y,color='blue')
pola = ['/','/','/','/','x','x','x','x']

# berikut digunakan fungsi 'for' untuk mengurutkan variabel hist
for bar in hist :
    # fungsi 'set_hatch()' digunakan untuk pola di dalam batang
    bar.set_hatch(pola.pop(0))

# berikut fungsi 'show()' yang digunakan untuk mengeluarkan output figure
plt.show()
